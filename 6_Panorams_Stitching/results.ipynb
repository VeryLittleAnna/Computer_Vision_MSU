# %% [markdown]
# # 4. Преобразование всех кадров в плоскость центрального

# %% [markdown]
# ### `00_04_simple_warps.jpeg`
# ![00_04_simple_warps.jpeg](attachment:00_04_simple_warps.jpeg)

# %% [markdown]
# ### `00_05_final_warps.jpeg`
# ![00_05_final_warps.jpeg](attachment:00_05_final_warps.jpeg)

# %% [markdown]
# ### `01_04_simple_warps.jpeg`
# ![01_04_simple_warps.jpeg](attachment:01_04_simple_warps.jpeg)

# %% [markdown]
# ### `01_05_final_warps.jpeg`
# ![01_05_final_warps.jpeg](attachment:01_05_final_warps.jpeg)

# %% [markdown]
# ### `02_04_simple_warps.jpeg`
# ![02_04_simple_warps.jpeg](attachment:02_04_simple_warps.jpeg)

# %% [markdown]
# ### `02_05_final_warps.jpeg`
# ![02_05_final_warps.jpeg](attachment:02_05_final_warps.jpeg)

# %% [markdown]
# ### `03_04_simple_warps.jpeg`
# ![03_04_simple_warps.jpeg](attachment:03_04_simple_warps.jpeg)

# %% [markdown]
# ### `03_05_final_warps.jpeg`
# ![03_05_final_warps.jpeg](attachment:03_05_final_warps.jpeg)

# %% [markdown]
# ### `04_04_simple_warps.jpeg`
# ![04_04_simple_warps.jpeg](attachment:04_04_simple_warps.jpeg)

# %% [markdown]
# ### `04_05_final_warps.jpeg`
# ![04_05_final_warps.jpeg](attachment:04_05_final_warps.jpeg)

# %% [markdown]
# # 5. Совмещение всех кадров на изображении

# %% [markdown]
# ### `00_06_base_pano.jpeg`
# ![00_06_base_pano.jpeg](attachment:00_06_base_pano.jpeg)

# %% [markdown]
# ### `01_06_base_pano.jpeg`
# ![01_06_base_pano.jpeg](attachment:01_06_base_pano.jpeg)

# %% [markdown]
# ### `02_06_base_pano.jpeg`
# ![02_06_base_pano.jpeg](attachment:02_06_base_pano.jpeg)

# %% [markdown]
# ### `03_06_base_pano.jpeg`
# ![03_06_base_pano.jpeg](attachment:03_06_base_pano.jpeg)

# %% [markdown]
# ### `04_06_base_pano.jpeg`
# ![04_06_base_pano.jpeg](attachment:04_06_base_pano.jpeg)

# %% [markdown]
# # 6. Склеиваем панораму с помощью пирамиды Лапласа

# %% [markdown]
# ### `00_07_laplacian.jpeg`
# ![00_07_laplacian.jpeg](attachment:00_07_laplacian.jpeg)

# %% [markdown]
# ### `00_08_merged.jpeg`
# ![00_08_merged.jpeg](attachment:00_08_merged.jpeg)

# %% [markdown]
# ### `00_09_improved_pano.jpeg`
# ![00_09_improved_pano.jpeg](attachment:00_09_improved_pano.jpeg)

# %% [markdown]
# ### `01_07_laplacian.jpeg`
# ![01_07_laplacian.jpeg](attachment:01_07_laplacian.jpeg)

# %% [markdown]
# ### `01_08_merged.jpeg`
# ![01_08_merged.jpeg](attachment:01_08_merged.jpeg)

# %% [markdown]
# ### `01_09_improved_pano.jpeg`
# ![01_09_improved_pano.jpeg](attachment:01_09_improved_pano.jpeg)

# %% [markdown]
# ### `02_07_laplacian.jpeg`
# ![02_07_laplacian.jpeg](attachment:02_07_laplacian.jpeg)

# %% [markdown]
# ### `02_08_merged.jpeg`
# ![02_08_merged.jpeg](attachment:02_08_merged.jpeg)

# %% [markdown]
# ### `02_09_improved_pano.jpeg`
# ![02_09_improved_pano.jpeg](attachment:02_09_improved_pano.jpeg)

# %% [markdown]
# ### `03_07_laplacian.jpeg`
# ![03_07_laplacian.jpeg](attachment:03_07_laplacian.jpeg)

# %% [markdown]
# ### `03_08_merged.jpeg`
# ![03_08_merged.jpeg](attachment:03_08_merged.jpeg)

# %% [markdown]
# ### `03_09_improved_pano.jpeg`
# ![03_09_improved_pano.jpeg](attachment:03_09_improved_pano.jpeg)

# %% [markdown]
# ### `04_07_laplacian.jpeg`
# ![04_07_laplacian.jpeg](attachment:04_07_laplacian.jpeg)

# %% [markdown]
# ### `04_08_merged.jpeg`
# ![04_08_merged.jpeg](attachment:04_08_merged.jpeg)

# %% [markdown]
# ### `04_09_improved_pano.jpeg`
# ![04_09_improved_pano.jpeg](attachment:04_09_improved_pano.jpeg)

# %% [markdown]
# # 7. Выравнивание изображений с помощью цилиндрической проекции

# %% [markdown]
# ### `00_10_cylindrical_pano.jpeg`
# missing

# %% [markdown]
# ### `01_10_cylindrical_pano.jpeg`
# missing

# %% [markdown]
# ### `02_10_cylindrical_pano.jpeg`
# missing

# %% [markdown]
# ### `03_10_cylindrical_pano.jpeg`
# missing

# %% [markdown]
# ### `04_10_cylindrical_pano.jpeg`
# missing
